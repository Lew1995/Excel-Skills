# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

dataframe = pd.read_csv("/content/drive/MyDrive/online_gaming_behavior_dataset.csv")
dataframe.info()

dataframe["PlayerID"]
print(type(dataframe["PlayerID"]))

dataframe[["PlayerID", "Age"]]

dataframe.head(1)

dataframe.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40034 entries, 0 to 40033
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PlayerID                   40034 non-null  int64
#  1   Age                        40034 non-null  int64
#  2   Gender                     40034 non-null  object
#  3   Location                   40034 non-null  object
#  4   GameGenre                  40034 non-null  object
#  5   PlayTimeHours              40034 non-null  float64
#  6   InGamePurchases            40034 non-null  int64
#  7   GameDifficulty             40034 non-null  object
#  8   SessionsPerWeek            40034 non-null  int64
#  9   AvgSessionDurationMinutes  40034 non-null  int64
#  10  PlayerLevel                40034 non-null  int64
#  11  AchievementsUnlocked       40034 non-null  int64
#  12  EngagementLevel            40034 non-null  object
# ...

# %%
dataframe[(dataframe['Gender'] == "Male") & (dataframe['GameDifficulty'] == "Easy") & (dataframe["EngagementLevel"] == "High")]
# Out:
#        PlayerID  Age Gender Location   GameGenre  PlayTimeHours  \
# 5          9005   37   Male   Europe         RPG      20.561855
# 14         9014   44   Male      USA  Simulation      17.975200
# 53         9053   45   Male   Europe  Simulation      23.702897
# 64         9064   43   Male    Other      Sports      14.627357
# 77         9077   49   Male      USA    Strategy      18.535366
# ...         ...  ...    ...      ...         ...            ...
# 39955     48955   41   Male      USA      Sports      20.112600
# 39980     48980   19   Male   Europe      Sports       9.993380
# 40000     49000   44   Male      USA  Simulation       8.801141
# 40018     49018   45   Male   Europe  Simulation       5.950284
# 40027     49027   17   Male   Europe  Simulation       1.273467
#
#        InGamePurchases GameDifficulty  SessionsPerWeek  \
# 5                    0           Easy                2
# 14                   0           Easy                8
# ...
